# %%
import pandas as pd

# %%
a=pd.read_csv(r"/content/drive/MyDrive/Depression/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/OpenSmileFeatures/AIC_301_result_slice_0_lowerlevel.csv")

# %%
a.head()
# Out:
#                     start  ... F3amplitudeLogRelF0_sma3nz
# 0         0 days 00:00:00  ...                     -201.0
# 1  0 days 00:00:00.010000  ...                     -201.0
# 2  0 days 00:00:00.020000  ...                     -201.0
# 3  0 days 00:00:00.030000  ...                     -201.0
# 4  0 days 00:00:00.040000  ...                     -201.0
#
# [5 rows x 27 columns]

# %%
a.plot(x='end', y=['hammarbergIndex_sma3', 'mfcc2_sma3'], figsize=(30,15), kind='line')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f,axes=plt.subplots(13,2,figsize=(10,16), sharex=True, sharey=True)
axes = axes.flatten()
for au_ix, au_col in enumerate(cols):
      sns.lineplot(x='end', y=au_col, data=a, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      #axes[au_ix].legend(loc=5)
plt.suptitle("AU intensity predictions by time for each face")
plt.tight_layout()

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l[4:]:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  #au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,3), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_2"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_2/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_3"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_3/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_4"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_4/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_5"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_5/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_6"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_6/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
l=[]
for item in os.listdir(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_7"):
  if item[-3:]=='csv' and "(1)" not in item:
    l.append(item)

# %%
route=r"/content/drive/MyDrive/Video_AU_RML/CSV_Files_7/"
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
import re
sns.set_style('white')
import matplotlib.pyplot as plt 
for item in l:
# Load data
  df = pd.read_csv(route+item)
  # Remove empty spaces in column names.
  df.columns = [col.replace(" ", "") for col in df.columns]
  # Print few values of data.
  #print(f"Max number of frames {df.frame.max()}", f"\nTotal shape of dataframe {df.shape}")
  #df.head()
  # Threshold data by 80%
  df_clean = df[df.confidence>=.80]
  # Plot all Action Unit time series. 
  au_regex_pat = re.compile(r'^AU[0-9]+_r$')
  #au_columns = df.columns[df.columns.str.contains(au_regex_pat)]
  #print("List of AU columns:", au_columns)
  au_columns=t
  f,axes = plt.subplots(1, 3, figsize=(10,4), sharex=True, sharey=True)
  axes = axes.flatten()
  for au_ix, au_col in enumerate(au_columns):
      sns.lineplot(x='frame', y=au_col, hue='face_id', data=df_clean, ax=axes[au_ix])
      axes[au_ix].set(title=au_col, ylabel='Intensity')
      axes[au_ix].legend(loc=5)
  plt.suptitle("AU intensity predictions by time for each face")
  plt.tight_layout()
  plt.savefig(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3/"+item[:-4]+".png")
  plt.close()

# %%
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/AU_Plots_3")

# %%
for i in range(301,345):
  flag=0
  for item in w:
    if str(i) in item:
      flag=1
      break
  if flag==0:
    print(str(i)+"not in the directory.")

# %%
import re
au_regex_pat = re.compile(r'^AU[0-9]+_r$')

# %%
au_regex_pat

# %%
import pandas as pd
df = pd.read_csv(r"/content/drive/MyDrive/Video_AU_RML/CSV_Files/AI_101.csv")

# %%
df.columns = [col.replace(" ", "") for col in df.columns]

# %%
au_columns = df.columns[df.columns.str.contains(au_regex_pat)]

# %%
au_columns

# %%
au_columns.remove('AU01_r')

# %%
w=list(au_columns)

# %%
w.remove('AU01_r')

# %%
w=pd.Index(w)
