# %%
import os
import shutil

# %%
x=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz")

# %%
len(x)
# Out:
# 947

# %%
source=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/AIC_301_result_slice_0_lowerlevel.png"
destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Depressed/"
dest = shutil.move(source, destination)

# %%
dest
# Out:
# '/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Depressed/AIC_301_result_slice_0_lowerlevel.png'

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/"
for item in x:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/Depressed/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/Depressed/"
    dest = shutil.move(source, destination)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-bd62a3c9c5a6> in <module>()
# ----> 1 a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Healthy/")
#       2 b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Depressed/")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Healthy/'

# %%
source=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/Depressed/Healthy/"
destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/"
dest = shutil.move(source, destination)

# %%
a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/Depressed/")
b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F0semitoneFrom27.5Hz_sma3nz/Healthy")

# %%
len(a)+len(b)
# Out:
# 1944

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz")

# %%
os.mkdir("Depressed")
os.mkdir("Healthy")

# %%
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz")
len(w)
# Out:
# 1947

# %%
w

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz/Depressed/")
b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1amplitudeLogRelF0_sma3nz/Healthy")
len(a)+len(b)
# Out:
# 1945

# %%
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz")
len(w)
# Out:
# 1944

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz/Depressed/")
b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1bandwidth_sma3nz/Healthy")
len(a)+len(b)
# Out:
# 1944

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz")
print(len(w))
# Out:
# 1950

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz/Depressed/")
b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F1frequency_sma3nz/Healthy")
len(a)+len(b)
# Out:
# 1948

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz")
print(len(w))
# Out:
# 1951

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
a=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz/Depressed/")
b=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2amplitudeLogRelF0_sma3nz/Healthy")
len(a)+len(b)
# Out:
# 1949

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2bandwidth_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2bandwidth_sma3nz")
print(len(w))
# Out:
# 1946

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2bandwidth_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2bandwidth_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2bandwidth_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2frequency_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2frequency_sma3nz")
print(len(w))
# Out:
# 1951

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2frequency_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2frequency_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F2frequency_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3amplitudeLogRelF0_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3amplitudeLogRelF0_sma3nz")
print(len(w))
# Out:
# 1947

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3amplitudeLogRelF0_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3amplitudeLogRelF0_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3amplitudeLogRelF0_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3bandwidth_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3bandwidth_sma3nz")
print(len(w))
# Out:
# 1946

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3bandwidth_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3bandwidth_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3bandwidth_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3frequency_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3frequency_sma3nz")
print(len(w))
# Out:
# 1946

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3frequency_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3frequency_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/F3frequency_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz")
print(len(w))
# Out:
# 1946

# %%
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz")
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/HNRdBACF_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/hammarbergIndex_sma3")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/hammarbergIndex_sma3")
print(len(w))
# Out:
# 1720

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/hammarbergIndex_sma3/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/hammarbergIndex_sma3/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/hammarbergIndex_sma3/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/jitterLocal_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/jitterLocal_sma3nz")
print(len(w))

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/jitterLocal_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/jitterLocal_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/jitterLocal_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/logRelF0-H1-A3_sma3nz")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/logRelF0-H1-A3_sma3nz")
print(len(w))

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/logRelF0-H1-A3_sma3nz/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/logRelF0-H1-A3_sma3nz/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/logRelF0-H1-A3_sma3nz/Depressed/"
      dest = shutil.move(source, destination)

# %%
os.chdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3")
os.mkdir("Depressed")
os.mkdir("Healthy")
w=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3")
print(len(w))
# Out:
# 1946

# %%
route= r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/"
for item in w:
  if "AIC" in item:
    source=route+item
    destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Healthy/"
    dest = shutil.move(source, destination) 
  else:
    if item !="Healthy":
      source=route+item
      destination=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/Depressed/"
      dest = shutil.move(source, destination)

# %%
import os

# %%
parent=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots")

# %%
route=r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/"
total=0
for item in parent:
  a=os.listdir(route+item+"/"+"Depressed")
  b=os.listdir(route+item+"/"+"Healthy")
  if len(a)+len(b)>=1944:
    print(item+" has more than or equal to 1944")
    total+=1
# Out:
# mfcc4_sma3 has more than or equal to 1944
# hammarbergIndex_sma3 has more than or equal to 1944
# spectralFlux_sma3 has more than or equal to 1944
# slope500-1500_sma3 has more than or equal to 1944
# mfcc1_sma3 has more than or equal to 1944
# mfcc3_sma3 has more than or equal to 1944
# mfcc2_sma3 has more than or equal to 1944
# Loudness_sma3 has more than or equal to 1944
# slope0-500_sma3 has more than or equal to 1944
# F0semitoneFrom27.5Hz_sma3nz has more than or equal to 1944
# jitterLocal_sma3nz has more than or equal to 1944
# shimmerLocaldB_sma3nz has more than or equal to 1944
# HNRdBACF_sma3nz has more than or equal to 1944
# logRelF0-H1-H2_sma3nz has more than or equal to 1944
# logRelF0-H1-A3_sma3nz has more than or equal to 1944
# F1frequency_sma3nz has more than or equal to 1944
# F1bandwidth_sma3nz has more than or equal to 1944
# F1amplitudeLogRelF0_sma3nz has more than or equal to 1944
# F2frequency_sma3nz has more than or equal to 1944
# ...

# %%
total
# Out:
# 25

# %%
len(parent)
# Out:
# 25
