# %%
# !pip install ffmpeg pydub
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=635c79499708892875adb473edd4ef9fd7a937de32c6a1bb2855197897e869d6
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %%
from pydub import AudioSegment
for i in range(301,350):
  j=0
  while True:
    try:
      src=r"/content/drive/MyDrive/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/Audio_Slices_Healthy/AIC_"+str(i)+"_result_slice_"+str(j)+".mp3"
      dst=r"/content/drive/MyDrive/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/WAV_Audio/AIC_"+str(i)+"_result_slice_"+str(j)+".wav"
      audSeg = AudioSegment.from_mp3(src)
      audSeg.export(dst, format="wav")
      j+=70000
    except:
      break
