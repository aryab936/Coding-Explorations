# %%
# !pip install pydub

# %%
# !pip install ffmpeg
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=0c3ed1a0918fc9436a9ece8267abc410ed435092387bea923865762fe9a3d565
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %%
from pydub import AudioSegment, silence

# %%
audio=AudioSegment.from_mp3(r"/content/drive/MyDrive/Depression_Detection/Without_Slicing/Depressed_People_Audio/AI_101_result.mp3")

# %%
a=silence.detect_silence(audio)

# %%
louder_audio = audio+ 6

# %%
w=silence.detect_silence(louder_audio)

# %%
louder_audio_2=audio+12

# %%
x=silence.detect_silence(louder_audio_2)

# %%
len(w)
# Out:
# 138

# %%
len(x)
# Out:
# 258

# %%
louder_audio_3=audio+18
y=silence.detect_silence(louder_audio_3)

# %%
len(a)
# Out:
# 1

# %%
len(y)
# Out:
# 91

# %%
louder_audio_4=audio+24
t=silence.detect_silence(louder_audio_4)

# %%
a
# Out:
# [[0, 1264130]]
