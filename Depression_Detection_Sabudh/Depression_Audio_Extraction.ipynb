# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ffmpeg pydub
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=9ed33f006653852773a2095137cf8ab5764bc741704dcf357d20fbd26622b04e
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %%
# !pip install mutagen
# Out:
# ...
#      |████████████████████████████████| 218 kB 23.5 MB/s
# ...

# %%
from pydub import AudioSegment

# %%
# !pip install moviepy

# %%
import moviepy.editor as mp
my_clip = mp.VideoFileClip(r"/content/drive/MyDrive/Video_AU_RML/Converted_MP4/AI_106.mp4")
my_clip.audio.write_audiofile(r"AI_106_result.mp3")
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# [MoviePy] Writing audio in AI_106_result.mp3
# 100%|██████████| 28856/28856 [00:56<00:00, 512.62it/s]
# [MoviePy] Done.

# %% [markdown]
# # RUN FROM HERE

# %%
from mutagen.mp3 import MP3
audio=MP3(r"/content/drive/MyDrive/AI_depression_Vid_Aud/depressed_folks/AIC_341_result.mp3")
audio_info=audio.info
length_in_seconds=int(audio_info.length)
print(length_in_seconds)
# Out:
# 1544

# %%
audio=AudioSegment.from_mp3(r"/content/drive/MyDrive/AI_depression_Vid_Aud/depressed_folks/AIC_341_result.mp3")

# %%
quotient=length_in_seconds//300
i=0
for i in range(quotient+1):
    if i==quotient:
      audio_crop=audio[i*300000:]
      filename="/content/drive/MyDrive/AI_depression_Vid_Aud/depressed_folks/AIC_341_result_slice_"+str(i)+".mp3"
      audio_crop.export(filename,format="mp3")
    else:
      audio_crop=audio[i*300000:(i+1)*300000]
      filename=r"/content/drive/MyDrive/AI_depression_Vid_Aud/depressed_folks/AIC_341_result_slice_"+str(i)+".mp3"
      audio_crop.export(filename,format="mp3")

# %%
#pip install ffmpeg pydub
#pip install mutagen
#pip install moviepy
from pydub import AudioSegment
import moviepy.editor as mp
from mutagen.mp3 import MP3
def extract_full_audio(video_file_path, destination_path):
  #destination_path must be a file ending in .mp3
  my_clip = mp.VideoFileClip(video_file_path)
  my_clip.audio.write_audiofile(destination_path)
  return 
def slice_audio(original_file_path, original_duration, overlapping_duration, destination_path):
  #original_file_path must be the path to an MP3 file
  audio=MP3(original_file_path)
  audio_info=audio.info
  length_in_seconds=int(audio_info.length)
  #print(length_in_seconds)
  audio=AudioSegment.from_mp3(original_file_path)
  j=0
  for j in list(range(0,length_in_seconds*1000-(original_duration+overlapping_duration),original_duration)):
    audio_crop=audio[j:j+(overlapping_duration+original_duration)]
    filename=destination_path+str(i)+"_result_slice_"+str(int(j/1000))+".mp3"
    audio_crop.export(filename,format="mp3")
  return
