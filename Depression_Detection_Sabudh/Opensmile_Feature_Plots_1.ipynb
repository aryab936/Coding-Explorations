# %%
import pandas as pd
data=pd.read_csv(r"/content/drive/MyDrive/Depression/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/OpenSmileFeatures/AIC_301_result_slice_0_lowerlevel.csv")

# %%
data.head()
# Out:
#                     start  ... F3amplitudeLogRelF0_sma3nz
# 0         0 days 00:00:00  ...                     -201.0
# 1  0 days 00:00:00.010000  ...                     -201.0
# 2  0 days 00:00:00.020000  ...                     -201.0
# 3  0 days 00:00:00.030000  ...                     -201.0
# 4  0 days 00:00:00.040000  ...                     -201.0
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
data.plot(x='end', y='Loudness_sma3', figsize=(30,10), color='crimson')
plt.savefig('my_out.png')

# %%
import os
x=os.listdir(r"/content/drive/MyDrive/Depression/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/OpenSmileFeatures")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
x=os.listdir(r"/content/drive/MyDrive/Depression/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/OpenSmileFeatures")
y=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3")
y=[item[:-4]+".csv" for item in y]
for item in y:
  if item in x:
    x.remove(item)
route=r"/content/drive/MyDrive/Depression/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/OpenSmileFeatures/"
for item in x:
  if "lowerlevel" in item:
    data=pd.read_csv(route+item)
    data.plot(x='end', y='alphaRatio_sma3', figsize=(30,10), color='teal')
    plt.savefig(r'/content/drive/MyDrive/Depression_Current/OpenSmilePlots/alphaRatio_sma3/'+item[:-4]+".png")
    plt.close('all')

# %%
y=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/Loudness_sma3")

# %%
y=[item[:-4]+".csv" for item in y]

# %%
len(y)
# Out:
# 820

# %%
len(x)
# Out:
# 3888

# %%
for item in y:
  if item in x:
    x.remove(item)

# %%
len(x)
# Out:
# 3068

# %%
y=os.listdir(r"/content/drive/MyDrive/Depression_Current/OpenSmilePlots/Loudness_sma3")
len(y)
# Out:
# 1944

# %%
1944*2
# Out:
# 3888
