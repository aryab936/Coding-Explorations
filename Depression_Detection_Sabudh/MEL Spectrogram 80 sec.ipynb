# %%
# !pip install librosa
import librosa
import numpy as np
import matplotlib.pyplot as plt
from librosa import display

# %%
for i in range (301,346):
  j=0
  while(True):
    try:
        audio_file=r"/content/drive/MyDrive/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/Audio_Slices_Healthy/AIC_"+str(i)+"_result_slice_"+str(j)+".mp3"
        y,sr=librosa.load(audio_file)
        mel_features=librosa.feature.melspectrogram(y,sr, n_mels=40)
        
        fig,ax=plt.subplots()
        mel_features = librosa.power_to_db(mel_features, ref=np.max)
        img = display.specshow(mel_features, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)
        fig.colorbar(img, ax=ax, format='%+2.0f dB')
        ax.set(title='Mel-frequency spectrogram')
        savename=r"/content/drive/MyDrive/Depression_Detection/Slicing_Experiment/70_sec_and_10_overlap/Spectrograms_Healthy/Mel_AIC_"+str(i)+"_result_slice_"+str(j)+".png"
        fig.savefig(savename)
        plt.close('all')  
        j+=70000
    except:
      break
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...

# %%
def make_spectrogram(audio_file_path, fig_save_name):
  y,sr=librosa.load(audio_file)
  mel_features=librosa.feature.melspectrogram(y,sr, n_mels=40)
  fig,ax=plt.subplots()
  mel_features = librosa.power_to_db(mel_features, ref=np.max)
  img = display.specshow(mel_features, x_axis='time',y_axis='mel', sr=sr,fmax=8000, ax=ax)
  fig.colorbar(img, ax=ax, format='%+2.0f dB')
  ax.set(title='Mel-frequency spectrogram')
  fig.savefig(fig_save_name)
  plt.close('all')  
  return
